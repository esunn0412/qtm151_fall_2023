# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your Emory ID below

# %%
# Write your answer here
print(2626784)
# Out:
# 2626784

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should your run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing Random Variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a uniform distribution with (low = 10, high = 20, size = 1000)
# - Generate "vec_z" from a chi-square distribution with (df = 1, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code:
vec_x = np.random.uniform(low=10, high=20, size=1000)
vec_z = np.random.chisquare(df=1, size=1000)

plt.hist(x=vec_x)
plt.xlabel("Values of vec_x")
plt.xlabel("Frequency")
plt.title("Distribution of vec_x with different simulated samples")
plt.show()
plt.hist(x=vec_z)
plt.xlabel("Values of vec_z")
plt.xlabel("Frequency")
plt.title("Distribution of vec_z with different simulated samples")
plt.show()

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = e^x + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "exp()" function with vector arrays

# %%
# Write your own code:
vec_y = []

for x in vec_x:
    y = np.exp(x)+(2*x)+5
    vec_y.append(y)


print(vec_y)
plt.scatter(vec_x, vec_y, color = "red")
plt.xlabel("vec_x")
plt.ylabel("vec_y")
plt.title("relationship between vec_x and vec_y")
# Out:
# [50094800.575099, 181697.14858949927, 3820723.2302094856, 190039875.35062027, 48069556.12212502, 5556489.256183847, 65469.11483988207, 230160084.72279465, 9753450.076263243, 16211257.574322803, 238589.15240635225, 108420033.5091032, 115016.89946346507, 108392.09871544824, 317041559.241774, 20324002.575149905, 27879689.517882913, 2561430.4543602793, 33432601.63962934, 541651.6090540203, 269378195.9345355, 55497908.937690444, 15190948.498281563, 30813.01500079374, 117340.17464923966, 157300368.0865308, 3109141.375001261, 392428527.82494676, 1351197.5077089563, 1351335.1265388154, 44748.85238668638, 2079717.6810291347, 23570.994792045578, 235160354.0586801, 364712.6094587083, 11490703.64354197, 19177013.46826822, 12614249.40772522, 751480.0427483389, 642401.1493908485, 1072345.122219876, 70989.29167564928, 787173.1039749383, 4405448.02446422, 228108549.75256687, 9161848.585970186, 75474974.23087454, 16697342.487302745, 168056.6332135067, 5665189.733926234, 1290006.1852174776, 468277.5632080252, 351625.022023828, 25508966.105402224, 8049184.195967861, 178636005.46312523, 493970.4417308243, 323240154.2911501, 4747691.810558029, 57385.54582040723, 83187.57006383096, 131946.24945284688, 63174834.81098568, 2773899.272384581, 106757744.34759001, 95424266.20861325, 2993154.816276738, 171671.30155248463, 26835238.075043395, 75924.05421096877, 124673.31007687829, 5108314.134007673, 549775.8501410123, 20200406.539964173, 172432.90933366446, 390912.2921344946, 419945265.6189327, 229089.2339310596, 906642.451511496, 14116242.652908614, 12648855.559876416, 27819.189891033035, 24338775.2618525, 5363937.742234189, 285973496.7752316, 20123275.03947927, 167444196.97025886, 3022845.3286095452, 134287408.60250798, 593174.4044212303, 1402997.7691416459, 1719299.3549129767, 48863.45218583657, 26515926.14124694, 3140688.596751224, 1357329.4036435972, 14650786.328717163, 28395.14286815395, 940384.1164286315, 123946152.5515867, 30430.04828169637, 2221033.3468020116, 32649586.581418004, 1267646.4323305406, 12972533.099824185, 290365470.0455959, 223352.3094734413, 8630240.46055464, 7996863.241973269, 13560062.655171528, 294683601.65920836, 5421775.226493902, 130305.13854288669, 22274.88310839775, 1955947.5306283438, 1096201.2885515932, 73094291.30018587, 14022023.364309093, 426376075.75518155, 39231.58010432678, 34125.0827299398, 101884676.34666306, 35786801.493850976, 8452825.836239422, 84247563.56806125, 76693.55645667728, 1792368.5013032798, 58681.15359842157, 28587591.442382097, 421659.1689217651, 18002803.759238753, 2646936.544981737, 33544.87436974168, 1413698.9309637016, 460056269.68366796, 35592.28017073435, 2848502.0497984295, 103295835.87394778, 3023022.7531233835, 942723.2162321005, 35438.73785958725, 39381.4615868775, 22848380.660493445, 29508.431419194883, 13986022.678727355, 185937466.16422656, 14528278.163678363, 48617.6035495162, 3022899.669388996, 7103618.583629636, 588073.2092824817, 306791.9297755169, 6075016.548541538, 2982536.696309932, 91730.93617721001, 667157.3164620677, 96791.06165654752, 45957.07923483124, 300942931.4460887, 174692163.31769738, 297616.48274847167, 8344977.524465875, 104555.72073052575, 26270899.092176206, 589169.9395732596, 89437263.0805004, 1670413.8792338138, 125197170.19996634, 6054522.067461405, 6554005.701779357, 49728.436667709495, 29180865.622823562, 433186154.32118654, 3741385.694379549, 454162426.9805942, 123869528.60246179, 384893.4591384911, 6680906.017694946, 50455279.65852669, 34040485.375197515, 1636245.7584833878, 229468.3106571467, 312108113.6756713, 29673655.181167487, 165655.48758476606, 172993098.07984716, 4309250.142559647, 108681094.71918991, 69199351.79945202, 57316112.58104609, 33340.05168998055, 43164.57360342402, 131262.85996247333, 21297871.696454175, 1810200.3688534729, 138957130.71184468, 484753436.19402826, 3064318.3844165304, 14708466.2562819, 30511936.210212775, 32711316.891995896, 291373.01022779697, 207198.75545897087, 444422174.64872086, 180652.30346914337, 101290.57192958401, 34 ...
# Text(0.5, 1.0, 'relationship between vec_x and vec_y')

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Creates two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on the distribution of ages worldwide

# %%
# Write your own code
names = ["wdi_ages1980", "wdi_ages2000", "wdi_ages2020"]
years = [1980, 2000, 2020]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2000, print the message
#
# $\qquad$ "This dataset contains information on or after 2000.
#
# - If the year $<$ 2000, print the message
#
# $\qquad$ "This dataset contains information before 2000"

# %%
# Write your own code
for i in years:
    if i>=2000: 
        print("This dataset contains information on or after 2000.")
    elif i<2000:
        print("This dataset contains information before 2000")
# Out:
# This dataset contains information before 2000
# This dataset contains information on or after 2000.
# This dataset contains information on or after 2000.

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "4">
#
# - **Before answering** this question do use your terminal (in Mac) or Anaconda prompt (in windows) to install the following package: ```conda install openpyxl```
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code:
alist = ["data_quiz/wdi_ages1980.csv", "data_quiz/wdi_ages2000.csv", "data_quiz/wdi_ages2020.csv"]
list_newnames =  ["data_excel/wdi_ages1980.xlsx", "data_excel/wdi_ages2000.xlsx", "data_excel/wdi_ages2020.xlsx"]
index = 0
for i in alist:
    dataset = pd.read_csv(alist[index])
    filename = list_newnames[index]
    dataset.to_excel("data_excel"+filename)
    index = index+1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb Cell 20 line 8
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a> dataset = pd.read_csv(alist[index])
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a> filename = list_newnames[index]
# ----> <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a> dataset.to_excel("data_excel"+filename)
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a> index = index+1
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/core/generic.py:2252, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2239 from pandas.io.formats.excel import ExcelFormatter
#    2241 formatter = ExcelFormatter(
#    2242     df,
#    2243     na_rep=na_rep,
#    (...)
#    2250     inf_rep=inf_rep,
#    2251 )
# -> 2252 formatter.write(
#    2253     excel_writer,
#    2254     sheet_name=sheet_name,
#    2255     startrow=startrow,
#    2256     startcol=startcol,
#    2257     freeze_panes=freeze_panes,
#    2258     engine=engine,
#    2259     storage_options=storage_options,
#    2260 )
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/formats/excel.py:934, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     930     need_save = False
#     931 else:
#     932     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     933     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 934     writer = ExcelWriter(  # type: ignore[abstract]
#     935         writer, engine=engine, storage_options=storage_options
#     936     )
#     937     need_save = True
#     939 try:
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ percent_ages0to14 = dataset["percent_ages0to14"] <br>
#     $\qquad$ percent_ages15to64 = dataset["percent_ages15to64"]
#
#     - Calculate the percent of the population between ages 0 and 64 by adding the two previous variables
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code:
alist = ["data_quiz/wdi_ages1980.csv", "data_quiz/wdi_ages2000.csv", "data_quiz/wdi_ages2020.csv"]
index = 0
for i in alist:
    dataset = pd.read_csv[alist[index]]
    percent_ages0to14 = dataset["percent_ages0to14"]
    percent_ages15to64 = dataset["percent_ages15to64"]
    percent = percent_ages0to14+percent_ages15to64
    plt.hist(percent)
    plt.xlabel("percent population between ages 0 and 64")
    plt.ylabel("frequency")
    plt.show()
    index=index+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb Cell 22 line 5
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a> index = 0
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X55sZmlsZQ%3D%3D?line=3'>4</a> for i in alist:
# ----> <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X55sZmlsZQ%3D%3D?line=4'>5</a>     dataset = pd.read_csv[alist[index]]
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X55sZmlsZQ%3D%3D?line=5'>6</a>     percent_ages0to14 = dataset["percent_ages0to14"]
#       <a href='vscode-notebook-cell:/Users/taeeunkim/Desktop/qtm151_fall_2023/quizzes/quiz1/quiz_1EDITED.ipynb#X55sZmlsZQ%3D%3D?line=6'>7</a>     percent_ages15to64 = dataset["percent_ages15to64"]
#
# TypeError: 'function' object is not subscriptable
